# %%
import grid2op

print(
    "The current local directory where the environment are downloaded is \n{}"
    "".format(grid2op.get_current_local_dir())
)
print(
    "The environments available without necessary download are: \n{}"
    "".format(grid2op.list_available_local_env())
)
print(
    "I can download these environments from the internet: \n{}"
    "".format(grid2op.list_available_remote_env())
)
# Out:
# The current local directory where the environment are downloaded is
# C:\Users\Balco\data_grid2op
# The environments available without necessary download are:
# ['l2rpn_2019', 'l2rpn_case14_sandbox']
# I can download these environments from the internet:
# ['l2rpn_2019', 'l2rpn_case14_sandbox', 'l2rpn_icaps_2021_large', 'l2rpn_icaps_2021_small', 'l2rpn_idf_2023', 'l2rpn_neurips_2020_track1_large', 'l2rpn_neurips_2020_track1_small', 'l2rpn_neurips_2020_track2_large', 'l2rpn_neurips_2020_track2_small', 'l2rpn_wcci_2020', 'l2rpn_wcci_2022', 'rte_case14_realistic', 'rte_case14_redisp', 'wcci_test']

# %%
# The automatic download isn't working correctly
# Uncomment these lines to download the environment through your web browser

# import grid2op.MakeEnv
# import grid2op.MakeEnv.Make

# env_name = "l2rpn_2019"  # for example, other environments might be usable
# grid2op.MakeEnv.Make._fecth_environments(env_name)

# %%
# Uncomment these lines to extract the environment file
# Modify the `output_path` accordingly

# import tarfile
# import os

# output_path = r"C:\Users\Balco\data_grid2op\l2rpn_2019.tar.bz2"
# path_data = grid2op.MakeEnv.PathUtils.DEFAULT_PATH_DATA

# tar = tarfile.open(output_path, "r:bz2")
# print('Extract the tar archive in "{}"'.format(os.path.abspath(path_data)))
# tar.extractall(path_data)
# tar.close()

# %%
# create an environment
env_name = "l2rpn_2019"  # for example, other environments might be usable
env = grid2op.make(env_name)
# Out:
# {'path': 'C:\\Users\\Balco\\data_grid2op\\l2rpn_2019\\chronics', 'gridvalueClass': <module 'grid2op.Chronics.readPypowNetData' from 'c:\\venvs\\grid2op\\Lib\\site-packages\\grid2op\\Chronics\\readPypowNetData.py'>}
# C:\Users\Balco\data_grid2op\l2rpn_2019\chronics
# []
# 1975687092224
#
# C:\Users\Balco\data_grid2op\l2rpn_2019\chronics
# {'path': 'C:\\Users\\Balco\\data_grid2op\\l2rpn_2019\\chronics', 'gridvalueClass': <module 'grid2op.Chronics.readPypowNetData' from 'c:\\venvs\\grid2op\\Lib\\site-packages\\grid2op\\Chronics\\readPypowNetData.py'>}
# C:\Users\Balco\data_grid2op\l2rpn_2019\chronics
# []
# 1975687092224
#
# C:\Users\Balco\data_grid2op\l2rpn_2019\chronics
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\venvs\grid2op\Lib\site-packages\grid2op\Chronics\chronicsHandler.py:83, in ChronicsHandler.__init__(self, chronicsClass, time_interval, max_iter, **kwargs)
#      81 try:
#      82     self._real_data = self.chronicsClass(
# ---> 83         time_interval=time_interval, max_iter=self.max_iter, **self.kwargs
#      84     )
#      85 except TypeError as exc_:
#
# File c:\venvs\grid2op\Lib\site-packages\grid2op\Chronics\chronicsHandler.py:108, in ChronicsHandler.kwargs(self)
#     106 @property
#     107 def kwargs(self):
# --> 108     res = copy.deepcopy(self._kwargs)
#     109     if self._real_data is not None:
#
# File ~\.pyenv\pyenv-win\versions\3.11.5\Lib\copy.py:176, in deepcopy(x, memo, _nil)
#     175 if copier is not None:
# --> 176     y = copier(x, memo)
#     177 else:
#
# File ~\.pyenv\pyenv-win\versions\3.11.5\Lib\copy.py:271, in _deepcopy_dict(x, memo, deepcopy)
#     270 for key, value in x.items():
# --> 271     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     272 return y
#
# File ~\.pyenv\pyenv-win\versions\3.11.5\Lib\copy.py:167, in deepcopy(x, memo, _nil)
#     166 print(x)
# --> 167 print(x["path"])
#     168 print(y)
#
# TypeError: string indices must be integers, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 # create an environment
#       2 env_name = "l2rpn_2019"  # for example, other environments might be usable
# ----> 3 env = grid2op.make(env_name)
#
# File c:\venvs\grid2op\Lib\site-packages\grid2op\MakeEnv\Make.py:473, in make(dataset, test, logger, experimental_read_from_local_dir, n_busbar, _add_to_name, _compat_glop_version, **kwargs)
#     471     if _aux_is_multimix(real_ds_path):
#     472         make_from_path_fn = _aux_make_multimix
# --> 473     return make_from_path_fn(
#     474         real_ds_path,
#     475         logger=logger,
#     476         n_busbar=n_busbar,
#     477         experimental_read_from_local_dir=experimental_read_from_local_dir,
#     478         **kwargs
#     479     )
#     481 # Env needs to be downloaded
#     482 warnings.warn(_MAKE_FIRST_TIME_WARN.format(dataset_name))
#
# File c:\venvs\grid2op\Lib\site-packages\grid2op\MakeEnv\MakeFromPath.py:631, in make_from_dataset_path(dataset_path, logger, experimental_read_from_local_dir, n_busbar, _add_to_name, _compat_glop_version, **kwargs)
#     629     data_feeding_kwargs = data_feeding_kwargs_res
#     630 # now build the chronics handler
# --> 631 data_feeding = _get_default_aux(
#     632     "data_feeding",
#     633     kwargs,
#     634     defaultClassApp=ChronicsHandler,
#     635     defaultClass=ChronicsHandler,
#     636     build_kwargs=data_feeding_kwargs,
#     637     msg_error=ERR_MSG_KWARGS["chronics_handler"],
#     638 )
#     640 ### other rewards
#     641 other_rewards_cfg = {}
#
# File c:\venvs\grid2op\Lib\site-packages\grid2op\MakeEnv\get_default_aux.py:176, in _get_default_aux(name, kwargs, defaultClassApp, _sentinel, msg_error, defaultinstance, defaultClass, build_kwargs, isclass)
#     174     raise EnvError(err_msg.format(name))
#     175 try:
# --> 176     res = defaultClass(**build_kwargs)
#     177 except Exception as e:
#     178     e.args = e.args + (
#     179         'Cannot create and instance of {} with parameters "{}"'.format(
#     180             defaultClass, build_kwargs
#     181         ),
#     182     )
#
# File c:\venvs\grid2op\Lib\site-packages\grid2op\Chronics\chronicsHandler.py:88, in ChronicsHandler.__init__(self, chronicsClass, time_interval, max_iter, **kwargs)
#      82     self._real_data = self.chronicsClass(
#      83         time_interval=time_interval, max_iter=self.max_iter, **self.kwargs
#      84     )
#      85 except TypeError as exc_:
#      86     raise ChronicsError(
#      87         "Impossible to build a chronics of type {} with arguments in "
# ---> 88         "{}".format(chronicsClass, self.kwargs)
#      89     ) from exc_
#
# File c:\venvs\grid2op\Lib\site-packages\grid2op\Chronics\chronicsHandler.py:108, in ChronicsHandler.kwargs(self)
#     106 @property
#     107 def kwargs(self):
# --> 108     res = copy.deepcopy(self._kwargs)
#     109     if self._real_data is not None:
#     110         self._real_data.get_kwargs(res)
#
# File ~\.pyenv\pyenv-win\versions\3.11.5\Lib\copy.py:176, in deepcopy(x, memo, _nil)
#     174 copier = _deepcopy_dispatch.get(cls)
#     175 if copier is not None:
# --> 176     y = copier(x, memo)
#     177 else:
#     178     if issubclass(cls, type):
#
# File ~\.pyenv\pyenv-win\versions\3.11.5\Lib\copy.py:271, in _deepcopy_dict(x, memo, deepcopy)
#     269 memo[id(x)] = y
#     270 for key, value in x.items():
# --> 271     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     272 return y
#
# File ~\.pyenv\pyenv-win\versions\3.11.5\Lib\copy.py:167, in deepcopy(x, memo, _nil)
#     164     return y
#     166 print(x)
# --> 167 print(x["path"])
#     168 print(y)
#     169 print(d)
#
# TypeError: ("string indices must be integers, not 'str'", 'Cannot create and instance of <class \'grid2op.Chronics.chronicsHandler.ChronicsHandler\'> with parameters "{\'path\': \'C:\\\\Users\\\\Balco\\\\data_grid2op\\\\l2rpn_2019\\\\chronics\', \'chronicsClass\': <class \'grid2op.Chronics.multiFolder.Multifolder\'>, \'gridvalueClass\': <module \'grid2op.Chronics.readPypowNetData\' from \'c:\\\\venvs\\\\grid2op\\\\Lib\\\\site-packages\\\\grid2op\\\\Chronics\\\\readPypowNetData.py\'>}"')

# %%
# create an agent
from grid2op.Agent import RandomAgent

my_agent = RandomAgent(env.action_space)

# proceed as you would any open ai gym loop
nb_episode = 1
step = 0
for ep in range(nb_episode):
    print(f"***Episode {ep}")
    # you perform in this case 10 different episodes
    obs = env.reset()
    # env.render()
    reward = env.reward_range[0]
    done = False
    while not done:
        print(f"  Step: {step}, Episode: {ep}")
        # here you loop on the time steps: at each step your agent receive an observation
        # takes an action
        # and the environment computes the next observation that will be used at the next step.
        act = my_agent.act(obs, reward, done)
        print(f"  Action: {act}")
        obs, reward, done, info = env.step(act)
        print(f"  Obs: {obs}")
        print(f"  Reward: {reward}")
        print(f"  Done: {done}")
        # print(f"  Info: {info}")
        # env.render()
        step += 1
        print()
# Out:
# ***Episode 0
#   Step: 0, Episode: 0
#   Action: This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - Switch status of 1 powerlines ([6])
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
#   Obs: <grid2op.Space.GridObjects.CompleteObservation_l2rpn_case14_sandbox object at 0x00000212D92E7950>
#   Reward: 63.66973114013672
#   Done: False
#
#   Step: 1, Episode: 0
#   Action: This action will:
# 	 - NOT change anything to the injections
# 	 - Modify the generators with redispatching in the following way:
# 	 	 - Redispatch "gen_1_0" of -3.75 MW
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
#   Obs: <grid2op.Space.GridObjects.CompleteObservation_l2rpn_case14_sandbox object at 0x00000212DD0B5BD0>
#   Reward: 63.330299377441406
#   Done: False
#
#   Step: 2, Episode: 0
#   Action: This action will:
# 	 - NOT change anything to the injections
# 	 - Modify the generators with redispatching in the following way:
# 	 	 - Redispatch "gen_2_1" of -7.50 MW
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
#   Obs: <grid2op.Space.GridObjects.CompleteObservation_l2rpn_case14_sandbox object at 0x00000212D92E7950>
#   Reward: 61.600669860839844
#   Done: False
#
#   Step: 3, Episode: 0
#   Action: This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - Set the bus of the following element(s):
# 	 	 - Assign bus 1 to line (extremity) id 0 [on substation 1]
# 	 	 - Assign bus 2 to line (origin) id 2 [on substation 1]
# 	 	 - Assign bus 1 to line (origin) id 3 [on substation 1]
# 	 	 - Assign bus 2 to line (origin) id 4 [on substation 1]
# 	 	 - Assign bus 2 to generator id 0 [on substation 1]
# 	 	 - Assign bus 1 to load id 0 [on substation 1]
#   Obs: <grid2op.Space.GridObjects.CompleteObservation_l2rpn_case14_sandbox object at 0x00000212D9472050>
#   Reward: 61.470314025878906
#   Done: False
#
#   Step: 4, Episode: 0
#   Action: This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - Change the bus of the following element(s):
# 	 	 - Switch bus of line (origin) id 8 [on substation 5]
# 	 	 - Switch bus of line (extremity) id 17 [on substation 5]
# 	 	 - Switch bus of generator id 2 [on substation 5]
# 	 - NOT force any particular bus configuration
#   Obs: <grid2op.Space.GridObjects.CompleteObservation_l2rpn_case14_sandbox object at 0x00000212DA990CD0>
#   Reward: -10.0
#   Done: True

# %%
obs.

# %%
env.render()
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)
